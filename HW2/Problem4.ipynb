# %%
# %pip install "git+https://github.com/AerosolKiller/netsci_toolkit@main"
# Out:
# ...
#   Cloning https://github.com/AerosolKiller/netsci_toolkit (to revision main) to /private/var/folders/2c/064zj4311gvb_kh76pglwwn40000gn/T/pip-req-build-pahqcoty
#   Running command git clone --filter=blob:none --quiet https://github.com/AerosolKiller/netsci_toolkit /private/var/folders/2c/064zj4311gvb_kh76pglwwn40000gn/T/pip-req-build-pahqcoty
#   Resolved https://github.com/AerosolKiller/netsci_toolkit to commit fa4d6158d5d908d1898d218e442595fe653843f7
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for netsci-toolkit: filename=netsci_toolkit-0.1.0-py3-none-any.whl size=5438 sha256=6e20fd14956d6d2feaa97ef8a24d7d84091a3b0f3cda6c07c283ea4cabde633c
#   Stored in directory: /private/var/folders/2c/064zj4311gvb_kh76pglwwn40000gn/T/pip-ephem-wheel-cache-6knq16x9/wheels/ab/9c/22/6462d9aaecf587e61aaad2a253c7b8bffb910a3a7b25da55b8
# Successfully built netsci-toolkit
# ...

# %%
import networkx as nx
import netsci_toolkit as nst

# %%
G = nx.path_graph(5)
print(nst.__all__)
print(nst.nx_bc(G))
# Out:
# ['degree_preserving_randomization', 'all_shortest_from', 'indicator_betweenness_unscaled', 'nx_bc', 'directed_1in1out_core', 'log_binned_pdf']
# {0: 0.0, 1: 3.0, 2: 4.0, 3: 3.0, 4: 0.0}
